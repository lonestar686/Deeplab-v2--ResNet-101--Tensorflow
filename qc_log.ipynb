# %%
# %matplotlib inline
import matplotlib.pyplot as plt

#
loss_value_file="./log.txt"
epochs=[]
losses=[]
with open(loss_value_file, "r") as f:
    #lines = f.readlines()
    for line in f:
        a,b = line.split(',')
        epochs.append(a)
        losses.append(b)
#
print(epochs[5], losses[5])
# probably not necessary
#import numpy as np
#epochs=np.array(epochs)
#losses=np.array(losses)
# Out:
# 5  2.217

# %%
#
plt.plot(epochs[0:500], losses[0:500])
